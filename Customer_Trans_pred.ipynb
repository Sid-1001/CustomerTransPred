# %% [markdown]
# # Team ID - 1135
# # Project ID - 1003

# %% [markdown]
# ## Team Members
# ### 1) Siddharth Nair
# ### 2) Sanakousar Tallihal
# ### 3) Narnavaram DilipKumar

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the dataset
data = pd.read_csv('train(1).csv')

# %%
data #Original Dataset
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 0       -9.2834  5.1187  18.6266  ...   4.4354   3.9642   3.1364   1.6910
# 1        7.0433  5.6208  16.5338  ...   7.6421   7.7214   2.5837  10.9516
# 2       -9.0837  6.9427  14.6155  ...   2.9057   9.7905   1.6704   1.6858
# 3       -1.8361  5.8428  14.9250  ...   4.4666   4.7433   0.7178   1.4214
# 4        2.4486  5.9405  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942
# ...         ...     ...      ...  ...      ...      ...      ...      ...
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# 0       18.5227  -2.3978   7.8784   8.5635  12.7803  -1.0914
# 1       15.4305   2.0339   8.1267   8.7889  18.3560   1.9518
# 2       21.6042   3.1417  -6.5213   8.2675  14.7222   0.3965
# 3       23.0347  -1.2706  -2.9275  10.2922  17.9697  -8.9996
# 4       13.2876  -1.5121   3.9267   9.5031  17.9974  -8.8104
# ...         ...      ...      ...      ...      ...      ...
# 199995  18.0249  -1.7939   2.1661   8.5326  16.6660 -17.8661
# 199996  22.2717   1.7337  -2.1651   6.7419  15.9054   0.3388
# 199997  23.5311  -1.5736   1.2832   8.7155  13.8329   4.1995
# 199998  20.4158  -0.0786   6.7980  10.0342  15.5289 -13.9001
# 199999  15.2101  -2.4907  -2.2342   8.1857  12.1284   0.1385
#
# [200000 rows x 202 columns]

# %%
#Check the shape pf dataset
data.shape
# Out:
# (200000, 202)

# %%
#Check the count of majority and minority class
sns.countplot(x=data['target'])

# %%
data['target'].value_counts()
# Out:
# 0    179902
# 1     20098
# Name: target, dtype: int64

# %%
#Check for null values 
data.isnull().sum()
# Out:
# ID_code    0
# target     0
# var_0      0
# var_1      0
# var_2      0
#           ..
# var_195    0
# var_196    0
# var_197    0
# var_198    0
# var_199    0
# Length: 202, dtype: int64

# %%
#Check for the description of each variable
data.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# 25%         5.254075       9.883175     -11.200350       4.767700
# 50%         6.825000      11.108250      -4.833150       5.385100
# 75%         8.324100      12.261125       0.924800       6.003000
# max        13.188300      16.671400      17.251600       8.447700
#
#                var_7          var_8  ...        var_190        var_191  \
# count  200000.000000  200000.000000  ...  200000.000000  200000.000000
# mean       16.545850       0.284162  ...       3.234440       7.438408
# std         3.418076       3.332634  ...       4.559922       3.023272
# min         5.349700     -10.505500  ...     -14.093300      -2.691700
# 25%        13.943800      -2.317800  ...      -0.058825       5.157400
# 50%        16.456800       0.393700  ...       3.203600       7.347750
# 75%        19.102900       2.937900  ...       6.406200       9.512525
# max        27.691800      10.151300  ...      18.440900      16.716500
#
#              var_192        var_193        var_194        var_195  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        1.927839       3.331774      17.993784      -0.142088
# std         1.478423       3.992030       3.135162       1.429372
# min        -3.814500     -11.783400       8.694400      -5.261000
# 25%         0.889775       0.584600      15.629800      -1.170700
# 50%         1.901300       3.396350      17.957950      -0.172700
# 75%         2.949500       6.205800      20.396525       0.829600
# max         8.402400      18.281800      27.928800       4.272900
#
#              var_196        var_197        var_198        var_199
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        2.303335       8.908158      15.870720      -3.326537
# std         5.454369       0.921625       3.010945      10.438015
# min       -14.209600       5.960600       6.299300     -38.852800
# 25%        -1.946925       8.252800      13.829700     -11.208475
# 50%         2.408900       8.888200      15.934050      -2.819550
# 75%         6.556725       9.593300      18.064725       4.836800
# max        18.321500      12.000400      26.079100      28.500700
#
# [8 rows x 201 columns]

# %%
sns.scatterplot(data.var_10,data.var_2,hue = data.target)

# %%
#Check for outliers
sns.boxplot(data.var_198)

# %%
#Checking correlation between all input variables
corr = data.corr()

# %%
corr
# Out:
#            target     var_0     var_1     var_2     var_3     var_4     var_5  \
# target   1.000000  0.052390  0.050343  0.055870  0.011055  0.010915  0.030979
# var_0    0.052390  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046
# var_1    0.050343 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902
# var_2    0.055870  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569
# var_3    0.011055  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253
# ...           ...       ...       ...       ...       ...       ...       ...
# var_195  0.028285  0.002073 -0.000785 -0.001070  0.001206  0.003706 -0.001274
# var_196  0.023608  0.004386 -0.000377  0.003952 -0.002800  0.000513  0.002880
# var_197 -0.035303 -0.000753 -0.004157  0.001078  0.001164 -0.000046 -0.000535
# var_198 -0.053000 -0.005776 -0.004861 -0.000877 -0.001651 -0.001821 -0.000953
# var_199  0.025434  0.003850  0.002287  0.003855  0.000506 -0.000786  0.002767
#
#             var_6     var_7     var_8  ...   var_190   var_191   var_192  \
# target   0.066731 -0.003025  0.019584  ...  0.055973  0.047114 -0.042858
# var_0    0.006983  0.002429  0.004962  ...  0.002752  0.000206 -0.005373
# var_1    0.003258  0.001511  0.004098  ...  0.006627  0.003621 -0.002604
# var_2    0.000883 -0.000991  0.002648  ...  0.000197  0.001285 -0.003400
# var_3   -0.000774  0.002500  0.003553  ...  0.000151  0.002445 -0.001530
# ...           ...       ...       ...  ...       ...       ...       ...
# var_195  0.001244  0.001854  0.001396  ...  0.004571  0.000870 -0.004745
# var_196  0.005378  0.001045 -0.003242  ... -0.000847  0.002466 -0.001386
# var_197 -0.003565  0.003466 -0.004583  ... -0.004974  0.000906 -0.000527
# var_198 -0.003025  0.000650  0.002950  ... -0.000153 -0.000067  0.003451
# var_199  0.006096 -0.001457  0.000854  ... -0.000404  0.003595 -0.001239
#
#           var_193   var_194   var_195   var_196   var_197   var_198   var_199
# target  -0.017709 -0.022838  0.028285  0.023608 -0.035303 -0.053000  0.025434
# var_0    0.001616 -0.001514  0.002073  0.004386 -0.000753 -0.005776  0.003850
# var_1    0.001153 -0.002557 -0.000785 -0.000377 -0.004157 -0.004861  0.002287
# var_2    0.000549  0.002104 -0.001070  0.003952  0.001078 -0.000877  0.003855
# var_3   -0.001699 -0.001054  0.001206 -0.002800  0.001164 -0.001651  0.000506
# ...           ...       ...       ...       ...       ...       ...       ...
# var_195 -0.003143 -0.001201  1.000000  0.002517 -0.004170 -0.000536  0.002042
# var_196 -0.005308 -0.005040  0.002517  1.000000 -0.000454  0.000253  0.000607
# var_197  0.005068  0.000884 -0.004170 -0.000454  1.000000  0.001183  0.004991
# var_198  0.001646  0.003194 -0.000536  0.000253  0.001183  1.000000 -0.004731
# var_199 -0.000552 -0.005615  0.002042  0.000607  0.004991 -0.004731  1.000000
#
# [201 rows x 201 columns]

# %%
sns.heatmap(corr,cmap = 'coolwarm')

# %%
col = data.columns.values[2:102]
col
# Out:
# array(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6',
#        'var_7', 'var_8', 'var_9', 'var_10', 'var_11', 'var_12', 'var_13',
#        'var_14', 'var_15', 'var_16', 'var_17', 'var_18', 'var_19',
#        'var_20', 'var_21', 'var_22', 'var_23', 'var_24', 'var_25',
#        'var_26', 'var_27', 'var_28', 'var_29', 'var_30', 'var_31',
#        'var_32', 'var_33', 'var_34', 'var_35', 'var_36', 'var_37',
#        'var_38', 'var_39', 'var_40', 'var_41', 'var_42', 'var_43',
#        'var_44', 'var_45', 'var_46', 'var_47', 'var_48', 'var_49',
#        'var_50', 'var_51', 'var_52', 'var_53', 'var_54', 'var_55',
#        'var_56', 'var_57', 'var_58', 'var_59', 'var_60', 'var_61',
#        'var_62', 'var_63', 'var_64', 'var_65', 'var_66', 'var_67',
#        'var_68', 'var_69', 'var_70', 'var_71', 'var_72', 'var_73',
#        'var_74', 'var_75', 'var_76', 'var_77', 'var_78', 'var_79',
#        'var_80', 'var_81', 'var_82', 'var_83', 'var_84', 'var_85',
#        'var_86', 'var_87', 'var_88', 'var_89', 'var_90', 'var_91',
#        'var_92', 'var_93', 'var_94', 'var_95', 'var_96', 'var_97',
#        'var_98', 'var_99'], dtype=object)

# %%
def boxplot(data,col):
    sns.set(style = 'whitegrid')
    fig,ax = plt.subplots(10,10,figsize = (20,20))
    i = 0
    
    for column in col:
        i+=1
        plt.subplot(10,10,i)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=9)
        
        
    plt.show()

# %%
boxplot(data,col)

# %%
col2 = data.columns.values[102:-1]
col2
# Out:
# array(['var_100', 'var_101', 'var_102', 'var_103', 'var_104', 'var_105',
#        'var_106', 'var_107', 'var_108', 'var_109', 'var_110', 'var_111',
#        'var_112', 'var_113', 'var_114', 'var_115', 'var_116', 'var_117',
#        'var_118', 'var_119', 'var_120', 'var_121', 'var_122', 'var_123',
#        'var_124', 'var_125', 'var_126', 'var_127', 'var_128', 'var_129',
#        'var_130', 'var_131', 'var_132', 'var_133', 'var_134', 'var_135',
#        'var_136', 'var_137', 'var_138', 'var_139', 'var_140', 'var_141',
#        'var_142', 'var_143', 'var_144', 'var_145', 'var_146', 'var_147',
#        'var_148', 'var_149', 'var_150', 'var_151', 'var_152', 'var_153',
#        'var_154', 'var_155', 'var_156', 'var_157', 'var_158', 'var_159',
#        'var_160', 'var_161', 'var_162', 'var_163', 'var_164', 'var_165',
#        'var_166', 'var_167', 'var_168', 'var_169', 'var_170', 'var_171',
#        'var_172', 'var_173', 'var_174', 'var_175', 'var_176', 'var_177',
#        'var_178', 'var_179', 'var_180', 'var_181', 'var_182', 'var_183',
#        'var_184', 'var_185', 'var_186', 'var_187', 'var_188', 'var_189',
#        'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195',
#        'var_196', 'var_197', 'var_198'], dtype=object)

# %%
boxplot(data,col2)

# %%
def plot_dist(data,col):
    sns.set(style = 'whitegrid')
    fig,ax = plt.subplots(10,10,figsize = (20,20))
    i = 0
    
    for column in col:
        i+=1
        plt.subplot(10,10,i)
        plt.xlabel(column,fontsize=9)
        
        sns.distplot(data[column])
    plt.show()

# %%
plot_dist(data,col)

# %% [markdown]
# ## EDA OBSERVATIONS
#
# ### 1) The dataset is highly imbalanced
# ### 2) Outliers are present in almost all variables
# ### 3) Almost all variables are normally distributed

# %%
column_names = data.drop(['target','ID_code'],axis=1).columns.values
column_names
# Out:
# array(['var_0', 'var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'var_6',
#        'var_7', 'var_8', 'var_9', 'var_10', 'var_11', 'var_12', 'var_13',
#        'var_14', 'var_15', 'var_16', 'var_17', 'var_18', 'var_19',
#        'var_20', 'var_21', 'var_22', 'var_23', 'var_24', 'var_25',
#        'var_26', 'var_27', 'var_28', 'var_29', 'var_30', 'var_31',
#        'var_32', 'var_33', 'var_34', 'var_35', 'var_36', 'var_37',
#        'var_38', 'var_39', 'var_40', 'var_41', 'var_42', 'var_43',
#        'var_44', 'var_45', 'var_46', 'var_47', 'var_48', 'var_49',
#        'var_50', 'var_51', 'var_52', 'var_53', 'var_54', 'var_55',
#        'var_56', 'var_57', 'var_58', 'var_59', 'var_60', 'var_61',
#        'var_62', 'var_63', 'var_64', 'var_65', 'var_66', 'var_67',
#        'var_68', 'var_69', 'var_70', 'var_71', 'var_72', 'var_73',
#        'var_74', 'var_75', 'var_76', 'var_77', 'var_78', 'var_79',
#        'var_80', 'var_81', 'var_82', 'var_83', 'var_84', 'var_85',
#        'var_86', 'var_87', 'var_88', 'var_89', 'var_90', 'var_91',
#        'var_92', 'var_93', 'var_94', 'var_95', 'var_96', 'var_97',
#        'var_98', 'var_99', 'var_100', 'var_101', 'var_102', 'var_103',
#        'var_104', 'var_105', 'var_106', 'var_107', 'var_108', 'var_109',
#        'var_110', 'var_111', 'var_112', 'var_113', 'var_114', 'var_115',
#        'var_116', 'var_117', 'var_118', 'var_119', 'var_120', 'var_121',
#        'var_122', 'var_123', 'var_124', 'var_125', 'var_126', 'var_127',
#        'var_128', 'var_129', 'var_130', 'var_131', 'var_132', 'var_133',
#        'var_134', 'var_135', 'var_136', 'var_137', 'var_138', 'var_139',
#        'var_140', 'var_141', 'var_142', 'var_143', 'var_144', 'var_145',
#        'var_146', 'var_147', 'var_148', 'var_149', 'var_150', 'var_151',
#        'var_152', 'var_153', 'var_154', 'var_155', 'var_156', 'var_157',
#        'var_158', 'var_159', 'var_160', 'var_161', 'var_162', 'var_163',
#        'var_164', 'var_165', 'var_166', 'var_167', 'var_168', 'var_169',
#        'var_170', 'var_171', 'var_172', 'var_173', 'var_174', 'var_175',
#        'var_176', 'var_177', 'var_178', 'var_179', 'var_180', 'var_181',
#        'var_182', 'var_183', 'var_184', 'var_185', 'var_186', 'var_187',
#        'var_188', 'var_189', 'var_190', 'var_191', 'var_192', 'var_193',
#        'var_194', 'var_195', 'var_196', 'var_197', 'var_198', 'var_199'],
#       dtype=object)

# %%
train_df = data.copy() ## will apply all functions in train_df
train_df
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 0       -9.2834  5.1187  18.6266  ...   4.4354   3.9642   3.1364   1.6910
# 1        7.0433  5.6208  16.5338  ...   7.6421   7.7214   2.5837  10.9516
# 2       -9.0837  6.9427  14.6155  ...   2.9057   9.7905   1.6704   1.6858
# 3       -1.8361  5.8428  14.9250  ...   4.4666   4.7433   0.7178   1.4214
# 4        2.4486  5.9405  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942
# ...         ...     ...      ...  ...      ...      ...      ...      ...
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# 0       18.5227  -2.3978   7.8784   8.5635  12.7803  -1.0914
# 1       15.4305   2.0339   8.1267   8.7889  18.3560   1.9518
# 2       21.6042   3.1417  -6.5213   8.2675  14.7222   0.3965
# 3       23.0347  -1.2706  -2.9275  10.2922  17.9697  -8.9996
# 4       13.2876  -1.5121   3.9267   9.5031  17.9974  -8.8104
# ...         ...      ...      ...      ...      ...      ...
# 199995  18.0249  -1.7939   2.1661   8.5326  16.6660 -17.8661
# 199996  22.2717   1.7337  -2.1651   6.7419  15.9054   0.3388
# 199997  23.5311  -1.5736   1.2832   8.7155  13.8329   4.1995
# 199998  20.4158  -0.0786   6.7980  10.0342  15.5289 -13.9001
# 199999  15.2101  -2.4907  -2.2342   8.1857  12.1284   0.1385
#
# [200000 rows x 202 columns]

# %% [markdown]
# # Outlier removal

# %%
for i in column_names:
    #print(i)
    #print(train_df.loc[:,i])
    q75,q25 = np.percentile(train_df.loc[:,i],[75,25])
    #print(q75 , q25)
    iqr = q75 - q25 
    min = q25 - (1.5*iqr)
    max = q75 + (1.5*iqr)
    #print(min , max)
    #print(train_df[train_df.loc[:,i]<min].index)
    train_df = train_df.drop(train_df[train_df.loc[:,i]<min].index)
    train_df = train_df.drop(train_df[train_df.loc[:,i]>max].index)

# %%
print("Total observations removed :",data.shape[0]-train_df.shape[0])
print(data.shape[0])
print(train_df.shape[0])
# Out:
# Total observations removed : 24927
# 200000
# 175073

# %%
train_df 
x2 = train_df.iloc[:,2:]
y2 = train_df.iloc[:,1]

# %% [markdown]
# # Sampling

# %%
train_df2 = data.copy()

# %%
train_df2
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 0       -9.2834  5.1187  18.6266  ...   4.4354   3.9642   3.1364   1.6910
# 1        7.0433  5.6208  16.5338  ...   7.6421   7.7214   2.5837  10.9516
# 2       -9.0837  6.9427  14.6155  ...   2.9057   9.7905   1.6704   1.6858
# 3       -1.8361  5.8428  14.9250  ...   4.4666   4.7433   0.7178   1.4214
# 4        2.4486  5.9405  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942
# ...         ...     ...      ...  ...      ...      ...      ...      ...
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# 0       18.5227  -2.3978   7.8784   8.5635  12.7803  -1.0914
# 1       15.4305   2.0339   8.1267   8.7889  18.3560   1.9518
# 2       21.6042   3.1417  -6.5213   8.2675  14.7222   0.3965
# 3       23.0347  -1.2706  -2.9275  10.2922  17.9697  -8.9996
# 4       13.2876  -1.5121   3.9267   9.5031  17.9974  -8.8104
# ...         ...      ...      ...      ...      ...      ...
# 199995  18.0249  -1.7939   2.1661   8.5326  16.6660 -17.8661
# 199996  22.2717   1.7337  -2.1651   6.7419  15.9054   0.3388
# 199997  23.5311  -1.5736   1.2832   8.7155  13.8329   4.1995
# 199998  20.4158  -0.0786   6.7980  10.0342  15.5289 -13.9001
# 199999  15.2101  -2.4907  -2.2342   8.1857  12.1284   0.1385
#
# [200000 rows x 202 columns]

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
X3 =  train_df2.iloc[:,2:]
Y3 = train_df2.iloc[:,1]
print(Counter(Y3))
oversample = RandomOverSampler(sampling_strategy='minority')
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X3, Y3)
# summarize class distribution
print(Counter(y_over))
# Out:
# Counter({0: 179902, 1: 20098})
# Counter({0: 179902, 1: 179902})

# %%
sns.scatterplot(X_over['var_10'],X_over['var_2'],hue=y_over)
# Out:
# C:\Users\Siddharth\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(data.var_10,data.var_2,hue = data.target)

# %% [markdown]
# ### Outlier model = X2,Y2 (train_df)
# ### Sampling model= X_over, y_over  (train_df2)

# %% [markdown]
# ## Algorithms to be used

# %% [markdown]
# ### Logistic regression
# ### K nearest neighbours
# ### Naive Bayes
# ### Random Forest

# %% [markdown]
# # Logistic Regression For XT2,YT2

# %%
X2 = train_df.iloc[:,2:]
Y2 = train_df.iloc[:,1]
Y2
# Out:
# 0         0
# 2         0
# 3         0
# 4         0
# 5         0
#          ..
# 199993    0
# 199994    0
# 199995    0
# 199997    0
# 199999    0
# Name: target, Length: 175073, dtype: int64

# %%
from sklearn.model_selection import train_test_split
XT2,Xt2,YT2,Yt2 = train_test_split(X2,Y2,test_size = 0.2,random_state = 42)

# %%
import statsmodels.api as sm

# %%
logreg = sm.Logit(YT2,XT2).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.227420
#          Iterations 8

# %%
logreg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 target   No. Observations:               140058
# Model:                          Logit   Df Residuals:                   139858
# Method:                           MLE   Df Model:                          199
# Date:                Thu, 20 May 2021   Pseudo R-squ.:                  0.2893
# Time:                        21:49:09   Log-Likelihood:                -31852.
# converged:                       True   LL-Null:                       -44819.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# var_0          0.0547      0.003     16.135      0.000       0.048       0.061
# var_1          0.0394      0.003     15.311      0.000       0.034       0.044
# var_2          0.0675      0.004     17.329      0.000       0.060       0.075
# var_3          0.0173      0.005      3.380      0.001       0.007       0.027
# var_4          0.0215      0.006      3.345      0.001       0.009       0.034
# var_5          0.0144      0.001     10.823      0.000       0.012       0.017
# var_6          0.2717      0.012     22.745      0.000       0.248       0.295
# var_7         -0.0004      0.003     -0.118      0.906      -0.006       0.006
# var_8          0.0184      0.003      5.863      0.000       0.012       0.025
# var_9         -0.1190      0.008    -14.183      0.000      -0.136      -0.103
# var_10        -0.0015      0.002     -0.769      0.442      -0.005       0.002
# var_11         0.0135      0.002      7.690      0.000       0.010       0.017
# var_12        -1.1289      0.054    -20.922      0.000      -1.235      -1.023
# var_13        -0.0376      0.002    -16.823      0.000      -0.042      -0.033
# var_162        0.0753      0.007     10.227      0.000       0.061       0.090
# var_163        0.0190      0.002      9.635      0.000       0.015       0.023
# var_164        0.0254      0.002     13.245      0.000       0.022       0.029
# var_165       -0.0360      0.002    -17.388      0.000      -0.040      -0.032
# var_166       -0.5076      0.028    -18.064      0.000      -0.563      -0.453
# var_167        0.0117      0.001      8.677      0.000       0.009       0.014
# var_168        0.0132      0.003      3.944      0.000       0.007       0.020
# var_169       -0.4169      0.028    -14.721      0.000      -0.472      -0.361
# var_170        0.0382      0.002     16.178      0.000       0.034       0.043
# var_171        0.0091      0.002      4.671      0.000       0.005       0.013
# var_172       -0.0145      0.001    -12.000      0.000      -0.017      -0.012
# var_173        0.0233      0.002     13.220      0.000       0.020       0.027
# var_174       -0.0283      0.001    -19.531      0.000      -0.031      -0.025
# var_175        0.0262      0.004      7.286      0.000       0.019       0.033
# var_176        0.0042      0.001      2.989      0.003       0.001       0.007
# var_177       -0.0492      0.004    -12.338      0.000      -0.057      -0.041
# var_178       -0.0065      0.001     -5.363      0.000      -0.009      -0.004
# var_179        0.0567      0.004     14.962      0.000       0.049       0.064
# var_180        0.0205      0.002     10.384      0.000       0.017       0.024
# var_181        0.0338      0.008      4.452      0.000       0.019       0.049
# var_182       -0.0035      0.001     -3.040      0.002      -0.006      -0.001
# var_183       -0.0016      0.002     -0.686      0.492      -0.006       0.003
# var_184        0.0174      0.001     15.592      0.000       0.015       0.020
# var_185       -0.0003      0.002     -0.136      0.892      -0.005       0.004
# var_186       -0.0340      0.003    -10.297      0.000      -0.041      -0.028
# var_187        0.0051      0.001      5.653      0.000       0.003       0.007
# var_188       -0.0290      0.003    -10.990      0.000      -0.034      -0.024
# var_189        0.0311      0.011      2.903      0.004       0.010       0.052
# var_190        0.0401      0.002     17.490      0.000       0.036       0.045
# var_191        0.0529      0.003     15.497      0.000       0.046       0.060
# var_192       -0.0997      0.007    -13.819      0.000      -0.114      -0.086
# var_193       -0.0197      0.003     -7.456      0.000      -0.025      -0.015
# var_194       -0.0215      0.003     -6.471      0.000      -0.028      -0.015
# var_195        0.0649      0.007      8.899      0.000       0.051       0.079
# var_196        0.0144      0.002      7.566      0.000       0.011       0.018
# var_197       -0.1324      0.011    -11.708      0.000      -0.155      -0.110
# var_198       -0.0564      0.003    -16.492      0.000      -0.063      -0.050
# var_199        0.0075      0.001      7.449      0.000       0.006       0.009
# ==============================================================================
# """

# %%
#predicting
logreg_predict = logreg.predict(Xt2)

# %%
y_predict = logreg_predict.round()

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(Yt2,y_predict)
# Out:
# array([[31185,   411],
#        [ 2544,   875]], dtype=int64)

# %%
from sklearn.metrics import roc_auc_score,auc

# %%
print("AUC SCORE IS :",roc_auc_score(Yt2,y_predict))
# Out:
# AUC SCORE IS : 0.6214574043733845

# %%
from sklearn.metrics import classification_report,roc_curve

# %%
a = classification_report(Yt2,y_predict)

# %%
fpr, tpr, _ = roc_curve(Yt2, logreg_predict)

#create ROC curve
plt.plot(fpr,tpr)
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Using LR SKLEARN for sampling model

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import train_test_split
XT_samp,Xt_samp,YT_samp,Yt_samp = train_test_split(X_over,y_over,test_size = 0.2,random_state=42)
# Out:
# Counter({0: 36047, 1: 35914})

# %%
logModel=LogisticRegression(C=0.0001, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, l1_ratio=None, max_iter=20000,
                   multi_class='auto', n_jobs=None, penalty='l2',
                   random_state=42, solver='lbfgs', tol=0.0001, verbose=0,
                   warm_start=False)
logModel.fit(XT_samp , YT_samp)
# Out:
# LogisticRegression(C=0.0001, max_iter=20000, random_state=42)

# %%
lr_score=logModel.score(Xt_samp,Yt_samp)
print('Accuracy of the logistic regression model :',lr_score)
# Out:
# Accuracy of the logistic regression model : 0.7698475563152263

# %%
from sklearn.model_selection import cross_val_score,cross_val_predict
#Cross validation prediction
cv_pred=cross_val_predict(logModel,Xt_samp,Yt_samp,cv=5)
#Cross validation score
cv_score=cross_val_score(logModel,Xt_samp,Yt_samp,cv=5)
print('cross_val_score :',np.average(cv_score))
# Out:
# cross_val_score : 0.7610511614197609

# %%
#Confusion matrix
cm=confusion_matrix(Yt_samp,cv_pred)
cm
# Out:
# array([[27588,  8459],
#        [ 8736, 27178]], dtype=int64)

# %%
scores=classification_report(Yt_samp,cv_pred)
print(scores)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76     36047
#            1       0.76      0.76      0.76     35914
#
#     accuracy                           0.76     71961
#    macro avg       0.76      0.76      0.76     71961
# weighted avg       0.76      0.76      0.76     71961

# %%
y_pred_proba = logModel.predict_proba(Xt_samp)[::,1]
fpr, tpr, _ = roc_curve(Yt_samp,  y_pred_proba)
auc = roc_auc_score(Yt_samp, y_pred_proba)


#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')

plt.xlabel('False Positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Random Forest for outlier model

# %%
X2 = train_df.iloc[:,2:]
Y2 = train_df.iloc[:,1]
# Out:
#           var_0   var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 0        8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187  18.6266
# 2        8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427  14.6155
# 3       11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428  14.9250
# 4        9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405  19.2514
# 5       11.4763 -2.3182  12.6080  8.6264  10.9621   3.5609  4.5322  15.2255
# ...         ...     ...      ...     ...      ...      ...     ...      ...
# 199993  13.2152 -5.8006   9.7260  6.5910  12.4612  -7.1652  6.0666  12.9887
# 199994  12.3925 -5.8821  11.2323  3.9237  10.4509  10.7262  7.0503  18.6968
# 199995  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709  15.1516
# 199997  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555  21.5571
# 199999  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839  15.2058
#
#          var_8   var_9  ...  var_190  var_191  var_192  var_193  var_194  \
# 0      -4.9200  5.7470  ...   4.4354   3.9642   3.1364   1.6910  18.5227
# 2      -4.9193  5.9525  ...   2.9057   9.7905   1.6704   1.6858  21.6042
# 3      -5.8609  8.2450  ...   4.4666   4.7433   0.7178   1.4214  23.0347
# 4       6.2654  7.6784  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876
# 5       3.5855  5.9790  ...  -6.3068   6.6025   5.2912   0.4403  14.9452
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 199993  4.8121  8.6043  ...   3.9357   8.8442   1.8096  -4.8314  22.0050
# 199994 -0.4976  6.0916  ...   1.3911   6.8687   3.7788   6.3378  14.4656
# 199995 -0.6209  5.6669  ...   6.1415  13.2305   3.9901   0.9388  18.0249
# 199997  0.1202  6.1629  ...   4.0651   5.4414   3.1032   4.8793  23.5311
# 199999 -0.4541  9.3688  ...   8.9842   1.6893   0.1276   0.3766  15.2101
#
#         var_195  var_196  var_197  var_198  var_199
# 0       -2.3978   7.8784   8.5635  12.7803  -1.0914
# 2        3.1417  -6.5213   8.2675  14.7222   0.3965
# 3       -1.2706  -2.9275  10.2922  17.9697  -8.9996
# 4       -1.5121   3.9267   9.5031  17.9974  -8.8104
# 5        1.0314  -3.6241   9.7670  12.5809  -4.7602
# ...         ...      ...      ...      ...      ...
# 199993   0.3916   6.7302   8.9709  14.5405   6.1149
# 199994  -1.4843  -3.9299   9.1164  16.3170  -7.5048
# 199995  -1.7939   2.1661   8.5326  16.6660 -17.8661
# 199997  -1.5736   1.2832   8.7155  13.8329   4.1995
# 199999  -2.4907  -2.2342   8.1857  12.1284   0.1385
#
# [175073 rows x 200 columns]

# %%
from sklearn.model_selection import train_test_split
XT2_rf,Xt2_rf,YT2_rf,Yt2_rf = train_test_split(X2,Y2,test_size = 0.2,random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF_model = RandomForestClassifier(class_weight='balanced',
                                 criterion='gini',
                                 max_depth=55,
                                 max_features='log2',
                                 min_samples_leaf=0.005,
                                 min_samples_split=0.005,
                                 n_estimators=190).fit(XT2_rf,YT2_rf)

# %%
RF_pred = RF_model.predict(Xt2_rf)

# %%
from sklearn.metrics  import confusion_matrix

# %%
confusion_matrix(Yt2_rf,RF_pred)
# Out:
# array([[24726,  6870],
#        [  918,  2501]], dtype=int64)

# %%
from sklearn.metrics  import classification_report
cr=classification_report(Yt2_rf,RF_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86     31596
#            1       0.27      0.73      0.39      3419
#
#     accuracy                           0.78     35015
#    macro avg       0.62      0.76      0.63     35015
# weighted avg       0.90      0.78      0.82     35015

# %%
from sklearn.metrics import roc_curve,roc_auc_score
y_pred_proba_RF = RF_model.predict_proba(Xt2_rf)[::,1]
fpr, tpr, _ = roc_curve(Yt2_rf,  y_pred_proba_RF)
auc = roc_auc_score(Yt2_rf, y_pred_proba_RF)


#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')

plt.xlabel('False Positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # RF FOR SAMPLING MODEL

# %%
XT_samp_rf,Xt_samp_rf,YT_samp_rf,Yt_samp_rf = train_test_split(X_over,y_over,test_size = 0.2,random_state=42)
# Out:
#           var_0   var_1    var_2    var_3    var_4    var_5   var_6    var_7  \
# 62251    7.8389  1.0017  10.6478   8.0943  10.9869 -17.8885  5.0425  10.4300
# 286258  17.5050  2.5123   8.2022   7.0221  12.2560   7.7284  5.1438  19.3519
# 241202  10.3809 -2.4006  12.3119  11.2001  10.9349 -19.3732  5.2287  12.4432
# 41282   11.4621 -5.3236  12.4392  10.0310  11.9557  -2.8603  6.7248  16.1464
# 53404    9.9727 -5.6677  11.2523   8.0501  12.3751   5.1201  5.6629  24.2440
# ...         ...     ...      ...      ...      ...      ...     ...      ...
# 347668  14.1583 -2.3380   9.6478   8.0699  11.3214  -7.3917  6.1727  14.1740
# 225470  18.9058 -7.7938   5.8768  10.0764  11.4603   0.5334  4.2923  18.0535
# 202474   9.2279  0.4154   7.8890   5.0316  12.1944 -16.9417  5.1336  16.1082
# 95582    5.3793  0.6493  10.8456  10.3350   8.9552 -11.8398  6.6409  14.6047
# 289280  12.8133 -7.2196   8.3115   9.0170   9.6806  -6.4442  5.4578  17.1666
#
#          var_8   var_9  ...  var_190  var_191  var_192  var_193  var_194  \
# 62251   3.9426  6.8748  ...   0.8731   8.4191   2.6656   4.5051  15.2412
# 286258  2.1225  7.4407  ...   6.6855   6.7680  -1.0070  -3.2175  18.1409
# 241202 -3.0127  6.3899  ...   4.9214   8.3558   2.6393   3.6533  15.7697
# 41282  -3.3392  5.5566  ...  -0.0918   4.2586   0.1358   8.6907  20.4976
# 53404   0.5620  8.0594  ...   1.2376   3.5030   4.5914   3.0690  22.9240
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 347668 -1.6379  8.4161  ...   4.4550   5.5025   2.9774  -5.9567  21.6801
# 225470  3.5787  7.5815  ...   4.1836   3.6505   5.1625  -0.1056  11.0425
# 202474 -1.0261  6.1697  ...  -0.3253  14.5371   3.7302   5.7056  20.9389
# 95582  -2.6723  7.5878  ...  -2.2751   4.3046   2.3775   4.5372  12.0088
# 289280 -6.3712  8.2231  ...  -5.9135   6.5397   2.6351   1.9067  21.3008
#
#         var_195  var_196  var_197  var_198  var_199
# 62251    0.3989   5.4579   9.8282  19.6914   8.5930
# 286258   1.2328   2.3468   9.5802  14.8036  -1.2723
# 241202   0.1410   3.3011   9.1465  10.0789  -8.7970
# 41282   -0.1024   0.7727   8.2271  13.9082   0.8636
# 53404   -1.6698  -0.1935  10.1267   9.5984   8.3742
# ...         ...      ...      ...      ...      ...
# 347668   1.9825   0.7564   8.8330  20.3815 -21.3395
# 225470  -2.2965  -0.7601  10.4835  18.6681 -20.7115
# 202474  -1.9373   4.4283  10.3980  13.6167  -9.1592
# 95582    1.7133   4.4710   8.8850  21.2075  -2.8984
# 289280   0.0804   6.7949   7.7008  16.9119  -8.8653
#
# [71961 rows x 200 columns]

# %%
RF_model_samp = RandomForestClassifier(class_weight='balanced',
                                 criterion='gini',
                                 max_depth=55,
                                 max_features='log2',
                                 min_samples_leaf=0.005,
                                 min_samples_split=0.005,
                                 n_estimators=190).fit(XT_samp_rf,YT_samp_rf)

# %%
RF_pred_samp = RF_model_samp.predict(Xt_samp_rf)

# %%
confusion_matrix(Yt_samp_rf,RF_pred_samp)
# Out:
# array([[26907,  9140],
#        [ 6652, 29262]], dtype=int64)

# %%
from sklearn.metrics  import classification_report
cr=classification_report(Yt_samp_rf,RF_pred_samp)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77     36047
#            1       0.76      0.81      0.79     35914
#
#     accuracy                           0.78     71961
#    macro avg       0.78      0.78      0.78     71961
# weighted avg       0.78      0.78      0.78     71961

# %%
from sklearn.metrics import roc_curve,roc_auc_score
y_pred_proba_RF_samp = RF_model.predict_proba(Xt_samp_rf)[::,1]
fpr, tpr, _ = roc_curve(Yt_samp_rf,  y_pred_proba_RF_samp)
auc = roc_auc_score(Yt_samp_rf, y_pred_proba_RF_samp)


#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')

plt.xlabel('False Positive Rate')
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.model_selection import train_test_split
X_train_samp_knn, X_test_samp_knn, y_train_samp_knn, y_test_samp_knn = train_test_split(X_over, y_over, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
X_train1_samp_knn = std_scaler.fit_transform(X_train_samp_knn)
X_test1_samp_knn =std_scaler.transform(X_test_samp_knn)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
model.fit(X_train1_samp_knn,y_train_samp_knn)

y_predict= model.predict(X_test1_samp_knn)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
y_proba = model.predict_proba(X_test1_samp_knn)[:,1]


from sklearn.metrics import roc_curve,roc_auc_score,auc
# %matplotlib inline
#y_predict = model.predict_proba(X_test1_samp_knn)[:,1]
fpr, tpr, thresholds = roc_curve(y_test_samp_knn,y_proba)
auc=roc_auc_score(y_test_samp_knn,y_proba)
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.plot(fpr, tpr,color='green',label="AUC="+str(auc))
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %%
accuracy_score(y_test_samp_knn,y_predict)
# Out:
# 0.9494726310084629

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
y_proba_train = model.predict_proba(X_train1_samp_knn)[:,1]


from sklearn.metrics import roc_curve,roc_auc_score,auc
# %matplotlib inline
#y_predict = model.predict_proba(X_test1_samp_knn)[:,1]
fpr, tpr, thresholds = roc_curve(y_train_samp_knn,y_proba_train)
auc=roc_auc_score(y_train_samp_knn,y_proba_train)
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.plot(fpr, tpr,color='green',label="AUC="+str(auc))
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %%
pd.crosstab(y_test_samp_knn,y_predict)
# Out:
# col_0       0      1
# target
# 0       33040   3007
# 1         629  35285

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
NB_model = GaussianNB().fit(XT_samp,YT_samp)

# %%
NB_pred = NB_model.predict(Xt_samp)

# %%
pd.crosstab(Yt_samp,NB_pred)
# Out:
# col_0       0      1
# target
# 0       29292   6755
# 1        7182  28732

# %%
y_proba_NB = NB_model.predict_proba(Xt_samp)[:,1]
fpr, tpr, thresholds = roc_curve(Yt_samp,y_proba_NB)
auc=roc_auc_score(Yt_samp,y_proba_NB)
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.plot(fpr, tpr,color='green',label="AUC="+str(auc))
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # For outlier model

# %%
xT,xt,yT,yt = train_test_split(x2,y2,test_size = 0.2,random_state=42)

# %%
NB_model2 = GaussianNB().fit(xT,yT)

# %%
NB_pred2 = NB_model.predict(xt)

# %%
NB_pred2.shape
# Out:
# (35015,)

# %%
pd.crosstab(yt,NB_pred2)
# Out:
# col_0       0     1
# target
# 0       26016  5580
# 1         717  2702

# %%
y_proba_NB2 = NB_model.predict_proba(xt)[:,1]
fpr, tpr, thresholds = roc_curve(yt,y_proba_NB2)
auc=roc_auc_score(yt,y_proba_NB2)
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.plot(fpr, tpr,color='green',label="AUC="+str(auc))
plt.plot([0,1],[0,1],'r--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.0])
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Algorithms and scores
#
#
# #### Note - The metric used for score evaluation is AUC score and the ROC_AUC curve as it is a preferred choice of metric for imbalanced dataset

# %% [markdown]
# ## Algorithm on outlier models and their              Score
# ### Logistic Regression                                        0.62
# ### Random Forest                                               0.83
# ###  Naive Bayes                                                   0.88

# %% [markdown]
# ## Algorithm on Sampled model and their score
# ### Logistic Regression 0.85
# ### Random Forest 0.87
# ### Naive Bayes 0.88
# ### KNN    0.98

# %% [markdown]
# ### Note - KNN hasnt been applied on Outlier model as it is very sensitive to imbalanced dataset and will give very poor results

# %% [markdown]
# # Conclusions

# %% [markdown]
# ### KNN is giving a good result for sampled model
# ### If the requirement is not to apply anything to the dataset like sampling then the preferred algorithms would be Random Forests and Naive Bayes
# ### The preferance of algorithms for sampled dataset will be as follows
# ### 1)KNN 2)Naive Bayes  3)Random Forest 4) Logistic Regression

# %% [markdown]
# ## Note - If low latency model is a requirement then logistic regression would be a preferred choice as it has low time and space complexities and gives a pretty decent score also
